# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from random import random
from math import sqrt 
prob = {}
t=1e-5
for i in int_words:
    if i in prob: 
        prob[i]+=1
    else: 
        prob[i]=1
for i in prob: 
    prob[i]=1 - sqrt(t/(prob[i]/len(int_words)))
train_words = [x for x in int_words if random()>prob[x]]
#train_words = # The final subsampled word list

# %%
print ( train_words.count(vocab_to_int["the"]))
print ( int_words.count(vocab_to_int["the"]))
# Out:
# 13135
# 1061396

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randrange
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = randrange(1, window_size+1)
    #print (R)
    return list (set (words[max(idx-R,0):idx] + words[idx+1:idx+R+1]) ) 
    # Your code here
    
print (get_target(train_words, 0, 5))
print (train_words[:10])
print (train_words[0])
# Out:
# [741, 10571, 3133]
# [5233, 3133, 741, 10571, 27349, 15067, 58112, 854, 3580, 190]
# 5233

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y
x, y = next(get_batches(train_words, 10))
print (len(set(x))) 
print (y)
# Out:
# 10
# [741, 3133, 741, 10571, 5233, 27349, 15067, 58112, 10571, 5233, 27349, 854, 15067, 3133, 58112, 741, 5233, 27349, 15067, 3133, 58112, 10571, 741, 15067, 58112, 10571, 27349, 854, 15067, 854, 58112, 10571, 27349, 15067, 3580, 190, 190, 854, 58112, 15067, 3580, 854]

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=(None))
    labels = tf.placeholder(dtype=tf.int32, shape=(None,1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, +1, dtype=tf.float32)) 
                                                # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(dtype=tf.float32, shape=(n_vocab, n_embedding), stddev=0.1))
                            # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab, dtype=tf.float32))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b,
                                      labels=labels,
                                      inputs=embed, 
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab
                                     ) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7050 0.2741 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6454 0.2424 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5087 0.2251 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5672 0.2440 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5182 0.2499 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5288 0.2376 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5522 0.2229 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5374 0.2320 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4764 0.2245 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4379 0.2175 sec/batch
# Nearest to system: phosphates, enosis, interferons, inaccuracies, dueling, docteur, bachelor, donna,
# Nearest to be: chiuchow, drama, ij, speller, condition, kroner, harmonium, tzi,
# Nearest to where: clary, lucilla, pecos, vena, cubs, bodmin, sibilants, baracoa,
# Nearest to only: sempron, athlete, narratives, lease, grand, teatro, macdonald, idol,
# Nearest to most: piacenza, greet, shea, permission, lobbies, foal, policemen, baptized,
# Nearest to one: flows, reasoning, pawson, exhibits, data, mouthpieces, displays, initialism,
# Nearest to three: toppled, stringer, wept, criminal, whittaker, clifton, dummar, shareware,
# Nearest to can: representatives, contemporaneous, dieu, ein, rosalyn, same, sip, rapunzel,
# Nearest to dr: diagonal, zechariah, boer, puckett, soir, photons, jeannie, amazon,
# Nearest to freedom: antiproton, karaca, mcdermott, smg, swept, enumeration, phallic, qubit,
# Nearest to versions: guayaquil, jenna, regrettable, licklider, weiner, widened, fatboy, rakolta,
# Nearest to pressure: steppe, sniper, carnatic, describes, lovable, eraser, marpeck, pointing,
# Nearest to writers: bitnet, gardnerian, functioning, burhanuddin, stencil, bonilla, picasso, quartic,
# Nearest to engine: reads, servicemen, bouldering, fellini, urng, trna, dickensian, nicer,
# Nearest to pope: poverty, nobility, reciprocated, busan, artistry, bestows, templo, nast,
# Nearest to existence: isa, strunk, ay, snafu, inactivation, ene, temptations, kraft,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4908 0.2323 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4132 0.2162 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3314 0.2498 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2226 0.2413 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1822 0.2180 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1616 0.2165 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0958 0.2173 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0770 0.2139 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0142 0.2144 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9863 0.2141 sec/batch
# Nearest to system: phosphates, enosis, bachelor, november, muscles, privilege, setting, interferons,
# Nearest to be: chiuchow, condition, ij, drama, strength, speller, kroner, purchasing,
# Nearest to where: today, cubs, metre, or, transactions, bodmin, vena, magnus,
# Nearest to only: narratives, sempron, lease, macdonald, grand, athlete, populace, baha,
# Nearest to most: greet, policemen, piacenza, shea, believe, permission, change, baptized,
# Nearest to one: flows, reasoning, exhibits, data, tension, equally, displays, commercial,
# Nearest to three: criminal, technology, toppled, clifton, since, wept, whittaker, stringer,
# Nearest to can: same, representatives, or, contemporaneous, rosalyn, contributing, ein, feature,
# Nearest to dr: boer, division, marsh, puckett, diagonal, protect, increasing, csl,
# Nearest to freedom: antiproton, swept, phallic, enumeration, forgotten, paved, karaca, mcdermott,
# Nearest to versions: guayaquil, weiner, flattening, five, widened, scandinavia, note, feature,
# Nearest to pressure: describes, sniper, steppe, pointing, carnatic, set, filmmaking, chooses,
# Nearest to writers: bitnet, functioning, gardnerian, merged, burhanuddin, stencil, participating, weinberg,
# Nearest to engine: reads, fellini, servicemen, bouldering, visitation, recover, tyburn, moyers,
# Nearest to pope: poverty, nobility, busan, gehenna, nast, templo, namesake, reciprocated,
# Nearest to existence: until, kinetics, isa, whole, doctors, territorial, negatives, man,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9205 0.2156 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9260 0.2137 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9038 0.2140 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8786 0.2141 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8213 0.2142 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8213 0.2142 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8097 0.2140 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8063 0.2138 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7678 0.2141 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8007 0.2147 sec/batch
# Nearest to system: phosphates, enosis, bachelor, equilibrium, november, inaccuracies, dueling, flexibility,
# Nearest to be: condition, chiuchow, ij, drama, proven, speller, kroner, enables,
# Nearest to where: cubs, metre, today, elbows, welcomed, bodmin, clary, encoding,
# Nearest to only: narratives, sempron, athlete, grand, lease, macdonald, idol, effectiveness,
# Nearest to most: permission, greet, piacenza, shea, change, policemen, lobbies, baptized,
# Nearest to one: flows, six, newton, nine, mathematics, jurists, prevail, singer,
# Nearest to three: toppled, criminal, clifton, technology, empresses, wept, guinea, revue,
# Nearest to can: same, representatives, contemporaneous, or, dieu, rosalyn, tampa, theorem,
# Nearest to dr: boer, division, protect, diagonal, representatives, marsh, clues, puckett,
# Nearest to freedom: swept, enumeration, forgotten, mcdermott, antiproton, wages, orderly, phallic,
# Nearest to versions: guayaquil, weiner, scandinavia, flattening, recognized, regrettable, widened, jenna,
# Nearest to pressure: describes, steppe, sniper, escape, carnatic, pointing, worker, billboard,
# Nearest to writers: bitnet, functioning, gardnerian, burhanuddin, quartic, merged, weinberg, picasso,
# Nearest to engine: reads, servicemen, fellini, visitation, bouldering, recover, trna, scarcely,
# Nearest to pope: poverty, nobility, gehenna, nast, disks, templo, wife, bestows,
# Nearest to existence: kinetics, isa, negatives, until, territorial, whole, darwinists, itanium,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7792 0.2200 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7483 0.2265 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7342 0.2151 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7106 0.2145 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7412 0.2159 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7118 0.2171 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6949 0.2153 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7407 0.2148 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7191 0.2149 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6620 0.2145 sec/batch
# Nearest to system: phosphates, enosis, equilibrium, bachelor, muscles, inaccuracies, plutonium, arno,
# Nearest to be: condition, proven, chiuchow, ij, speller, drama, motives, enables,
# Nearest to where: cubs, clary, metre, lucilla, welcomed, elbows, bodmin, reaping,
# Nearest to only: narratives, sempron, idol, lease, grand, falsity, macdonald, athlete,
# Nearest to most: piacenza, permission, greet, lobbies, change, baptized, shea, policemen,
# Nearest to one: six, nine, singer, zero, five, flows, born, eight,
# Nearest to three: toppled, clifton, wept, criminal, revue, guinea, eagerly, charlemagne,
# Nearest to can: same, or, dieu, theorem, subalgebra, rosalyn, logically, contemporaneous,
# Nearest to dr: boer, representatives, diagonal, division, protect, philistine, herod, soir,
# Nearest to freedom: enumeration, mcdermott, technician, swept, forgotten, wages, antiproton, madhava,
# Nearest to versions: guayaquil, flattening, jenna, regrettable, scandinavia, weiner, licklider, carr,
# Nearest to pressure: steppe, describes, sniper, carnatic, pointing, lovable, worker, trailing,
# Nearest to writers: bitnet, quartic, gardnerian, burhanuddin, functioning, weinberg, campion, merged,
# Nearest to engine: servicemen, reads, trna, visitation, tyburn, fellini, bouldering, moyers,
# Nearest to pope: nobility, poverty, nast, wife, gehenna, ivanovich, templo, busan,
# Nearest to existence: kinetics, isa, negatives, itanium, whole, territorial, until, temptations,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6601 0.2155 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6546 0.2162 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6087 0.2150 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6226 0.2151 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6271 0.2147 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6269 0.2148 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6280 0.1598 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5539 0.2151 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5295 0.2160 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4994 0.2152 sec/batch
# Nearest to system: phosphates, enosis, equilibrium, hardware, blackfriars, docteur, muscles, flexibility,
# Nearest to be: condition, proven, enables, speller, chiuchow, stereoisomers, pause, ij,
# Nearest to where: metre, clary, cubs, lucilla, reaping, discriminate, elbows, millenarian,
# Nearest to only: sempron, narratives, idol, falsity, effectiveness, adherents, baha, lease,
# Nearest to most: piacenza, permission, lobbies, greet, change, more, wanna, remind,
# Nearest to one: nine, singer, six, born, five, eight, naturalist, poet,
# Nearest to three: toppled, clifton, stringer, revue, charlemagne, wept, ne, habib,
# Nearest to can: theorem, or, same, dieu, logically, subalgebra, different, choose,
# Nearest to dr: boer, philistine, puckett, soir, gang, winwood, division, florence,
# Nearest to freedom: technician, enumeration, mcdermott, antiproton, madhava, forgotten, wages, smg,
# Nearest to versions: guayaquil, macroeconomics, flattening, licklider, carr, rakolta, regrettable, weiner,
# Nearest to pressure: steppe, carnatic, sniper, eraser, describes, pointing, lovable, telescope,
# Nearest to writers: bitnet, quartic, burhanuddin, gardnerian, weinberg, functioning, pythons, stencil,
# Nearest to engine: servicemen, trna, using, scarcely, tyburn, excellent, reads, fellini,
# Nearest to pope: nobility, wife, poverty, ivanovich, nast, templo, gehenna, founder,
# Nearest to existence: isa, negatives, kinetics, whole, racked, itanium, reisman, craftsmanship,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5347 0.2161 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4765 0.2150 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4744 0.2160 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5225 0.2144 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5007 0.2148 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4703 0.2146 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4358 0.2146 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4111 0.2157 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4280 0.2147 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4285 0.2142 sec/batch
# Nearest to system: phosphates, hardware, equilibrium, enosis, flexibility, blackfriars, muscles, docteur,
# Nearest to be: condition, proven, enables, stereoisomers, infinite, speller, pause, chiuchow,
# Nearest to where: discriminate, clary, cubs, lucilla, millenarian, metre, elbows, pecos,
# Nearest to only: sempron, narratives, falsity, effectiveness, idol, unaccounted, grand, grasps,
# Nearest to most: piacenza, lobbies, permission, change, greet, more, reacting, fsk,
# Nearest to one: nine, singer, six, five, zero, born, manifestos, wilhelm,
# Nearest to three: toppled, clifton, charlemagne, habib, ne, two, stringer, silvia,
# Nearest to can: or, theorem, different, logically, same, subalgebra, encryption, defining,
# Nearest to dr: gang, philistine, boer, soir, puckett, david, winwood, division,
# Nearest to freedom: technician, enumeration, madhava, mcdermott, wages, antiproton, forgotten, smg,
# Nearest to versions: guayaquil, licklider, compiler, macroeconomics, carr, regrettable, rakolta, flattening,
# Nearest to pressure: steppe, eraser, carnatic, sniper, pointing, ale, lovable, telescope,
# Nearest to writers: bitnet, quartic, weinberg, gardnerian, burhanuddin, pythons, campion, stencil,
# Nearest to engine: servicemen, trna, piping, using, excellent, multiplayer, tyburn, dickensian,
# Nearest to pope: nobility, wife, nast, ivanovich, templo, poverty, gehenna, owen,
# Nearest to existence: negatives, racked, kinetics, whole, isa, itanium, reisman, craftsmanship,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4256 0.2158 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4296 0.2148 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4378 0.2150 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4236 0.2159 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4093 0.2144 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4437 0.2148 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3703 0.2148 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3835 0.2143 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4195 0.2164 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4050 0.2156 sec/batch
# Nearest to system: phosphates, hardware, distributed, docteur, enosis, blackfriars, flexibility, equilibrium,
# Nearest to be: proven, condition, enables, chiuchow, subspace, plaintext, pause, stereoisomers,
# Nearest to where: discriminate, pecos, lucilla, clary, cubs, millenarian, metre, elbows,
# Nearest to only: sempron, narratives, idol, falsity, grasps, unaccounted, effectiveness, adherents,
# Nearest to most: permission, greet, piacenza, lobbies, change, known, fsk, wanna,
# Nearest to one: nine, five, six, zero, eight, born, singer, wilhelm,
# Nearest to three: toppled, two, six, five, ne, habib, charlemagne, silvia,
# Nearest to can: subalgebra, or, different, choose, same, acceleration, theorem, dieu,
# Nearest to dr: david, winwood, gang, puckett, boer, francesco, arag, philistine,
# Nearest to freedom: madhava, enumeration, wages, technician, mcdermott, pacifism, antiproton, propagates,
# Nearest to versions: compiler, guayaquil, licklider, macroeconomics, carr, feature, ie, rakolta,
# Nearest to pressure: steppe, eraser, ale, diagram, sniper, carnatic, telescope, lovable,
# Nearest to writers: bitnet, gardnerian, weinberg, quartic, creator, curran, pythons, burhanuddin,
# Nearest to engine: using, servicemen, piping, excellent, multiplayer, trna, alpha, dickensian,
# Nearest to pope: nobility, wife, nast, emphasised, templo, brother, ivanovich, founder,
# Nearest to existence: negatives, racked, whole, argument, kinetics, backspin, craftsmanship, worshipped,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3902 0.2160 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3807 0.2149 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3590 0.2150 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3777 0.2148 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4225 0.2155 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3610 0.2151 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3765 0.2149 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3869 0.2145 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3327 0.2149 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3261 0.2144 sec/batch
# Nearest to system: phosphates, hardware, docteur, distributed, megabytes, grieve, flexibility, blackfriars,
# Nearest to be: condition, enables, proven, stereoisomers, subspace, plaintext, bards, chiuchow,
# Nearest to where: discriminate, lucilla, clary, millenarian, pecos, cubs, christianization, scalars,
# Nearest to only: sempron, idol, narratives, unaccounted, grasps, falsity, have, effectiveness,
# Nearest to most: piacenza, permission, greet, known, fsk, change, lobbies, persson,
# Nearest to one: five, six, zero, nine, eight, manifestos, seven, repeaters,
# Nearest to three: two, six, toppled, five, total, caithness, habib, four,
# Nearest to can: subalgebra, choose, same, or, encryption, genetic, acceleration, adm,
# Nearest to dr: david, winwood, soir, puckett, gang, aldo, boer, arag,
# Nearest to freedom: madhava, wages, enumeration, technician, mcdermott, pacifism, propagates, smg,
# Nearest to versions: compiler, licklider, guayaquil, feature, macroeconomics, ie, architecture, ibm,
# Nearest to pressure: steppe, sniper, eraser, regenerate, carnatic, ale, lovable, telescope,
# Nearest to writers: bitnet, gardnerian, weinberg, quartic, curran, creator, philosophers, sveriges,
# Nearest to engine: servicemen, using, aircraft, multiplayer, piping, trna, automobile, excellent,
# Nearest to pope: nobility, wife, emphasised, nast, bestows, templo, brother, fabricius,
# Nearest to existence: racked, argument, negatives, backspin, man, kinetics, whole, craftsmanship,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3535 0.2171 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2854 0.2156 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3960 0.2151 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3648 0.2145 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3650 0.2147 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2827 0.2151 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3373 0.2139 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3572 0.2144 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2102 0.2149 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2967 0.2148 sec/batch
# Nearest to system: hardware, phosphates, distributed, docteur, november, megabytes, blackfriars, grieve,
# Nearest to be: condition, proven, enables, stereoisomers, chiuchow, subspace, denominators, ij,
# Nearest to where: discriminate, lucilla, millenarian, clary, pecos, cubs, tver, metre,
# Nearest to only: sempron, idol, unaccounted, narratives, falsity, grand, grasps, angering,
# Nearest to most: piacenza, greet, permission, known, fsk, machpelah, persson, centrosome,
# Nearest to one: nine, five, six, zero, eight, seven, two, born,
# Nearest to three: two, six, toppled, five, total, habib, four, zero,
# Nearest to can: subalgebra, choose, acceleration, or, genetic, logically, same, calculable,
# Nearest to dr: winwood, david, gang, puckett, soir, richardson, arag, boer,
# Nearest to freedom: madhava, wages, enumeration, mcdermott, pacifism, technician, monetary, propagates,
# Nearest to versions: compiler, feature, licklider, guayaquil, macroeconomics, ie, ibm, carr,
# Nearest to pressure: sniper, steppe, lovable, regenerate, eraser, ale, marpeck, alanine,
# Nearest to writers: bitnet, gardnerian, weinberg, curran, philosophers, quartic, creator, sveriges,
# Nearest to engine: aircraft, servicemen, using, engines, piping, automobile, trna, multiplayer,
# Nearest to pope: nobility, wife, nast, templo, emphasised, fabricius, brother, bestows,
# Nearest to existence: argument, racked, worshipped, backspin, craftsmanship, man, negatives, cava,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3102 0.2164 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2501 0.2164 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3487 0.1034 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2508 0.2151 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2423 0.2150 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2018 0.2157 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2032 0.2155 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1996 0.2146 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2425 0.2147 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1429 0.2147 sec/batch
# Nearest to system: hardware, phosphates, november, distributed, megabytes, docteur, service, impairments,
# Nearest to be: condition, enables, proven, chiuchow, bards, pause, stereoisomers, preceding,
# Nearest to where: lucilla, discriminate, millenarian, clary, pecos, cubs, tver, reaping,
# Nearest to only: sempron, idol, narratives, grand, unaccounted, but, falsity, fascio,
# Nearest to most: piacenza, machpelah, known, permission, greet, centrosome, fsk, carvings,
# Nearest to one: nine, five, six, zero, eight, two, seven, born,
# Nearest to three: two, six, toppled, five, one, total, zero, ne,
# Nearest to can: subalgebra, choose, acceleration, or, eat, genetic, firstly, adm,
# Nearest to dr: winwood, puckett, gang, david, soir, arag, richardson, dustin,
# Nearest to freedom: madhava, wages, enumeration, mcdermott, pacifism, technician, propagates, seminaries,
# Nearest to versions: compiler, licklider, feature, guayaquil, mac, ibm, carr, bridging,
# Nearest to pressure: steppe, sniper, regenerate, ale, eraser, alanine, lovable, telescope,
# Nearest to writers: bitnet, gardnerian, weinberg, philosophers, curran, sveriges, quartic, biographies,
# Nearest to engine: aircraft, engines, servicemen, using, automobile, piping, chromodynamics, excellent,
# Nearest to pope: nobility, templo, fabricius, wife, bestows, emphasised, gregory, nast,
# Nearest to existence: argument, backspin, man, racked, craftsmanship, worshipped, negatives, postulates,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2527 0.2161 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2310 0.2146 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2191 0.2151 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1212 0.2152 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1979 0.2148 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1473 0.2144 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1726 0.2141 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1767 0.2152 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1976 0.2149 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1885 0.2147 sec/batch
# Nearest to system: hardware, november, phosphates, docteur, timesharing, distributed, megabytes, impairments,
# Nearest to be: condition, enables, proven, stereoisomers, subspace, chiuchow, denominators, pause,
# Nearest to where: discriminate, lucilla, clary, millenarian, pecos, scalars, cubs, bodmin,
# Nearest to only: sempron, narratives, idol, unaccounted, sampling, grasps, grand, schmidt,
# Nearest to most: known, piacenza, machpelah, permission, store, greet, crank, fsk,
# Nearest to one: zero, five, nine, six, eight, two, seven, repeaters,
# Nearest to three: two, six, five, toppled, total, zero, four, one,
# Nearest to can: subalgebra, choose, or, acceleration, behavior, useful, genetic, eat,
# Nearest to dr: winwood, gang, puckett, dustin, soir, arag, arrogance, bumped,
# Nearest to freedom: madhava, wages, enumeration, pacifism, hayek, propagates, mcdermott, technician,
# Nearest to versions: compiler, licklider, feature, guayaquil, carr, bridging, mac, ibm,
# Nearest to pressure: steppe, ale, sniper, regenerate, alanine, eraser, pitted, supercharged,
# Nearest to writers: bitnet, gardnerian, weinberg, philosophers, curran, quartic, biographies, sveriges,
# Nearest to engine: aircraft, engines, servicemen, automobile, using, chromodynamics, piping, carbide,
# Nearest to pope: nobility, bestows, templo, fabricius, emphasised, brill, antioch, gregory,
# Nearest to existence: argument, man, backspin, negatives, worshipped, racked, craftsmanship, isa,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1659 0.2155 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2343 0.2146 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1760 0.2151 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1675 0.2155 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1895 0.2144 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1966 0.2145 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1784 0.2149 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1455 0.2142 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1329 0.2149 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1763 0.2158 sec/batch
# Nearest to system: hardware, november, distributed, docteur, phosphates, megabytes, impairments, timesharing,
# Nearest to be: condition, enables, subspace, chiuchow, stereoisomers, denominators, bards, proven,
# Nearest to where: discriminate, lucilla, clary, pecos, millenarian, persecuting, scalars, cubs,
# Nearest to only: sempron, idol, narratives, unaccounted, have, grand, schmidt, banzer,
# Nearest to most: known, piacenza, permission, machpelah, greet, prejudiced, coelacanth, boy,
# Nearest to one: nine, five, six, zero, eight, two, seven, three,
# Nearest to three: two, six, five, one, four, zero, total, toppled,
# Nearest to can: subalgebra, choose, adm, useful, sip, or, acceleration, firstly,
# Nearest to dr: winwood, gang, puckett, jeremy, dustin, richardson, quiet, bumped,
# Nearest to freedom: madhava, enumeration, wages, propagates, mcdermott, hayek, technician, pacifism,
# Nearest to versions: compiler, feature, licklider, guayaquil, carr, bridging, ie, ibm,
# Nearest to pressure: steppe, ale, sniper, regenerate, pitted, eraser, supercharged, alanine,
# Nearest to writers: bitnet, gardnerian, weinberg, philosophers, curran, ender, editor, biographies,
# Nearest to engine: engines, aircraft, servicemen, using, automobile, piping, chromodynamics, carbide,
# Nearest to pope: nobility, bestows, templo, fabricius, emphasised, longinus, gregory, reciprocated,
# Nearest to existence: argument, man, backspin, craftsmanship, kinetics, worshipped, isa, postulates,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1977 0.2160 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1605 0.2151 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1975 0.2147 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1914 0.2149 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1588 0.2159 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1333 0.2140 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1366 0.2146 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1205 0.2157 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2029 0.2152 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1831 0.2151 sec/batch
# Nearest to system: november, docteur, phosphates, hardware, distributed, impairments, timesharing, hif,
# Nearest to be: condition, bards, enables, chiuchow, subspace, preceding, pause, ij,
# Nearest to where: lucilla, persecuting, discriminate, clary, cubs, bodmin, tver, millenarian,
# Nearest to only: sempron, idol, narratives, grand, schmidt, have, macdonald, fascio,
# Nearest to most: known, piacenza, machpelah, permission, prejudiced, greet, tibeto, coelacanth,
# Nearest to one: nine, six, five, zero, eight, seven, two, three,
# Nearest to three: two, six, five, four, one, zero, toppled, total,
# Nearest to can: subalgebra, choose, adm, sip, behavior, firstly, useful, borel,
# Nearest to dr: winwood, richardson, jeremy, gang, puckett, arag, dustin, quiet,
# Nearest to freedom: madhava, enumeration, wages, mcdermott, technician, hayek, propagates, pacifism,
# Nearest to versions: compiler, licklider, feature, guayaquil, carr, ie, connes, bridging,
# Nearest to pressure: steppe, ale, regenerate, sniper, pitted, warsaw, riots, eraser,
# Nearest to writers: bitnet, gardnerian, weinberg, philosophers, curran, alumni, ender, sveriges,
# Nearest to engine: engines, aircraft, turbofans, servicemen, using, piping, reciprocating, kislev,
# Nearest to pope: nobility, bestows, templo, fabricius, emphasised, gregory, longinus, poverty,
# Nearest to existence: argument, man, backspin, kinetics, craftsmanship, racked, isa, postulates,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2356 0.2164 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1082 0.2148 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1426 0.2142 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1720 0.2143 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0542 0.2145 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1388 0.2164 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1262 0.2147 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0927 0.2147 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1865 0.0475 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0965 0.2148 sec/batch
# Nearest to system: hardware, november, docteur, distributed, timesharing, megabytes, previously, impairments,
# Nearest to be: enables, condition, pause, proven, preceding, chiuchow, subspace, treads,
# Nearest to where: lucilla, discriminate, clary, persecuting, bodmin, tver, cubs, pecos,
# Nearest to only: sempron, idol, have, sampling, narratives, unaccounted, grand, fascio,
# Nearest to most: known, piacenza, machpelah, cfa, permission, centrosome, prejudiced, coelacanth,
# Nearest to one: zero, nine, five, six, eight, two, seven, three,
# Nearest to three: two, six, five, one, four, zero, total, toppled,
# Nearest to can: subalgebra, choose, useful, adm, sip, calculable, or, manipulation,
# Nearest to dr: winwood, gang, puckett, richardson, jeremy, quiet, bumped, dustin,
# Nearest to freedom: madhava, enumeration, wages, hayek, mcdermott, propagates, pacifism, technician,
# Nearest to versions: compiler, mac, ibm, licklider, feature, windows, bridging, ie,
# Nearest to pressure: steppe, ale, sniper, regenerate, riots, pitted, warsaw, gholas,
# Nearest to writers: bitnet, gardnerian, philosophers, weinberg, curran, alumni, ender, sveriges,
# Nearest to engine: engines, aircraft, using, servicemen, automobile, turbofans, kislev, powered,
# Nearest to pope: nobility, longinus, poverty, bestows, fabricius, busan, templo, gregory,
# Nearest to existence: man, argument, backspin, postulates, craftsmanship, racked, territorial, isa,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0784 0.2164 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0896 0.2173 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0893 0.2145 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0578 0.2143 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0709 0.2149 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0195 0.2147 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0810 0.2147 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0829 0.2147 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1144 0.2145 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0367 0.2147 sec/batch
# Nearest to system: november, hardware, timesharing, impairments, docteur, satellite, distributed, phosphates,
# Nearest to be: condition, pause, enables, proven, modifications, treads, trivially, chiuchow,
# Nearest to where: lucilla, discriminate, clary, cubs, bodmin, persecuting, tver, christianization,
# Nearest to only: sempron, have, narratives, idol, banzer, but, sampling, grand,
# Nearest to most: known, machpelah, piacenza, more, centrosome, coelacanth, tibeto, resilient,
# Nearest to one: zero, nine, five, six, eight, two, seven, three,
# Nearest to three: two, six, five, one, four, zero, total, toppled,
# Nearest to can: subalgebra, useful, choose, adm, sip, borel, or, disjunction,
# Nearest to dr: winwood, gang, richardson, jeremy, puckett, quiet, arag, dustin,
# Nearest to freedom: madhava, enumeration, technician, mcdermott, hayek, propagates, wages, pacifism,
# Nearest to versions: compiler, licklider, flattening, bridging, ibm, guayaquil, mac, carr,
# Nearest to pressure: ale, regenerate, steppe, pitted, sniper, riots, mpa, eraser,
# Nearest to writers: bitnet, philosophers, gardnerian, weinberg, alumni, curran, ender, permeates,
# Nearest to engine: engines, aircraft, servicemen, automobile, kislev, reciprocating, turbofans, using,
# Nearest to pope: nobility, longinus, bestows, poverty, gregory, constantinople, fabricius, reciprocated,
# Nearest to existence: backspin, man, argument, craftsmanship, racked, postulates, territorial, isa,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0170 0.2161 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0554 0.2147 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0387 0.2151 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0674 0.2144 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0796 0.2148 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0501 0.2145 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0962 0.2145 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1171 0.2148 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0334 0.2164 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0450 0.2141 sec/batch
# Nearest to system: november, hardware, timesharing, distributed, impairments, satellite, setting, docteur,
# Nearest to be: condition, pause, trivially, denominators, bards, enables, of, subspace,
# Nearest to where: lucilla, discriminate, a, clary, cubs, bodmin, then, parent,
# Nearest to only: sempron, have, sampling, narratives, idol, but, angering, sorenson,
# Nearest to most: known, piacenza, machpelah, tibeto, resilient, cfa, prejudiced, more,
# Nearest to one: zero, nine, five, six, eight, two, seven, three,
# Nearest to three: two, six, five, one, zero, four, total, seven,
# Nearest to can: subalgebra, useful, adm, choose, or, manipulation, calculable, encryption,
# Nearest to dr: winwood, gang, richardson, jeremy, puckett, socialite, dustin, arag,
# Nearest to freedom: madhava, enumeration, hayek, propagates, pacifism, wages, mcdermott, technician,
# Nearest to versions: compiler, flattening, bridging, carr, licklider, tiber, guayaquil, connes,
# Nearest to pressure: ale, regenerate, steppe, sniper, pitted, mpa, riots, warsaw,
# Nearest to writers: bitnet, philosophers, gardnerian, alumni, weinberg, ender, curran, permeates,
# Nearest to engine: engines, aircraft, reciprocating, bathed, kislev, automobile, turbofans, jumo,
# Nearest to pope: bestows, longinus, nobility, constantinople, fabricius, pisa, poverty, gregory,
# Nearest to existence: backspin, man, argument, craftsmanship, postulates, racked, kinetics, territorial,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0620 0.2160 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0634 0.2147 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0849 0.2150 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0685 0.2152 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0372 0.2150 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0594 0.2147 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0851 0.2143 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0550 0.2150 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1074 0.2149 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0442 0.2155 sec/batch
# Nearest to system: november, satellite, impairments, timesharing, hardware, docteur, setting, distributed,
# Nearest to be: bards, condition, pause, trivially, modifications, hubris, denominators, treads,
# Nearest to where: lucilla, clary, discriminate, persecuting, bodmin, christianization, cubs, spires,
# Nearest to only: sempron, have, idol, grand, sampling, angering, lease, narratives,
# Nearest to most: known, piacenza, machpelah, tibeto, resilient, cfa, had, prejudiced,
# Nearest to one: nine, zero, six, five, eight, two, seven, three,
# Nearest to three: two, six, five, one, zero, four, total, seven,
# Nearest to can: subalgebra, adm, useful, sip, choose, manipulation, encryption, borel,
# Nearest to dr: winwood, richardson, gang, jeremy, arag, aunt, puckett, bumped,
# Nearest to freedom: madhava, enumeration, propagates, mcdermott, hayek, technician, pacifism, pertinent,
# Nearest to versions: compiler, flattening, licklider, bridging, carr, feature, idiom, windows,
# Nearest to pressure: regenerate, ale, steppe, riots, pitted, warsaw, sniper, orioles,
# Nearest to writers: bitnet, gardnerian, philosophers, alumni, weinberg, ender, sexton, novelists,
# Nearest to engine: engines, aircraft, reciprocating, kislev, bathed, automobile, turbofans, jumo,
# Nearest to pope: constantinople, bestows, longinus, nobility, fabricius, gregory, poverty, disks,
# Nearest to existence: backspin, man, craftsmanship, argument, postulates, kinetics, territorial, racked,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0519 0.2160 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0049 0.2145 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0445 0.2142 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0917 0.2155 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0824 0.2161 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1217 0.2151 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1202 0.2143 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0225 0.2145 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0477 0.2140 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0370 0.2140 sec/batch
# Nearest to system: november, impairments, timesharing, satellite, shunting, docteur, designator, multivibrator,
# Nearest to be: plaintext, denominators, pause, bards, condition, trivially, treads, modifications,
# Nearest to where: lucilla, clary, discriminate, bodmin, tver, persecuting, spires, vald,
# Nearest to only: sempron, have, grand, sampling, idol, narratives, unaccounted, lease,
# Nearest to most: known, piacenza, resilient, cfa, machpelah, tibeto, coelacanth, centrosome,
# Nearest to one: nine, zero, six, five, two, eight, seven, three,
# Nearest to three: two, six, five, one, four, zero, total, seven,
# Nearest to can: subalgebra, useful, adm, choose, sip, borel, calculable, manipulation,
# Nearest to dr: winwood, richardson, gang, jeremy, arag, clauses, socialite, aunt,
# Nearest to freedom: madhava, enumeration, mcdermott, hayek, propagates, pertinent, collectivism, pacifism,
# Nearest to versions: compiler, flattening, idiom, licklider, bridging, scandinavia, carr, encylopedia,
# Nearest to pressure: ale, regenerate, riots, steppe, pitted, lovable, sniper, warsaw,
# Nearest to writers: alumni, bitnet, gardnerian, philosophers, weinberg, ender, fellows, novelists,
# Nearest to engine: engines, aircraft, reciprocating, jumo, turbofans, kislev, bathed, powered,
# Nearest to pope: longinus, constantinople, gregory, poverty, fabricius, pisa, bestows, templo,
# Nearest to existence: craftsmanship, backspin, argument, territorial, man, postulates, kinetics, racked,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9765 0.2169 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0220 0.2151 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0084 0.2148 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0227 0.2145 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0859 0.2149 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0603 0.2064 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9963 0.2165 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9870 0.2151 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0052 0.2152 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9771 0.2151 sec/batch
# Nearest to system: november, timesharing, hardware, impairments, shunting, designator, satellite, rewritten,
# Nearest to be: condition, denominators, bards, preceding, pause, trivially, chiuchow, gleaned,
# Nearest to where: lucilla, clary, discriminate, persecuting, whores, bodmin, spires, parent,
# Nearest to only: sempron, have, sampling, narratives, idol, grand, angering, unaccounted,
# Nearest to most: known, piacenza, machpelah, resilient, had, more, coelacanth, prejudiced,
# Nearest to one: nine, zero, six, five, eight, two, seven, three,
# Nearest to three: two, six, one, five, four, zero, nine, seven,
# Nearest to can: subalgebra, useful, adm, choose, sip, manipulation, calculable, parade,
# Nearest to dr: winwood, richardson, gang, jeremy, clauses, arag, socialite, ormond,
# Nearest to freedom: enumeration, madhava, propagates, mcdermott, hayek, technician, pertinent, pacifism,
# Nearest to versions: compiler, bridging, windows, mac, flattening, tiber, licklider, language,
# Nearest to pressure: mpa, riots, regenerate, ale, pitted, lovable, steppe, orioles,
# Nearest to writers: alumni, bitnet, philosophers, gardnerian, novelists, ender, weinberg, fellows,
# Nearest to engine: engines, aircraft, jumo, reciprocating, powered, turbofans, kislev, automobile,
# Nearest to pope: longinus, poverty, gregory, constantinople, disks, eustace, fabricius, pisa,
# Nearest to existence: backspin, craftsmanship, territorial, postulates, argument, man, kinetics, racked,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9694 0.2162 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9409 0.2158 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0387 0.2144 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0105 0.2145 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0257 0.2148 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9918 0.2146 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9188 0.2150 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9547 0.2157 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9168 0.2141 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0064 0.2144 sec/batch
# Nearest to system: november, timesharing, impairments, shunting, hardware, designator, rewritten, exercise,
# Nearest to be: condition, bards, pause, modifications, plaintext, treads, gleaned, trivially,
# Nearest to where: lucilla, discriminate, a, clary, parent, bodmin, spires, nigh,
# Nearest to only: sempron, have, narratives, sampling, idol, angering, grand, but,
# Nearest to most: known, piacenza, resilient, coelacanth, as, per, tibeto, fsk,
# Nearest to one: nine, zero, five, six, two, eight, three, seven,
# Nearest to three: two, six, one, five, four, zero, nine, seven,
# Nearest to can: subalgebra, useful, adm, choose, encryption, sip, fmri, or,
# Nearest to dr: winwood, richardson, gang, arag, technology, jeremy, ormond, aunt,
# Nearest to freedom: enumeration, propagates, madhava, pertinent, mcdermott, technician, hayek, collectivism,
# Nearest to versions: compiler, flattening, tiber, licklider, scandinavia, encylopedia, idiom, windows,
# Nearest to pressure: regenerate, pitted, ale, mpa, lovable, orioles, riots, warsaw,
# Nearest to writers: bitnet, alumni, gardnerian, philosophers, ender, novelists, weinberg, bierce,
# Nearest to engine: engines, aircraft, jumo, reciprocating, kislev, turbofans, powered, listing,
# Nearest to pope: longinus, disks, bestows, fabricius, gregory, poverty, pisa, eustace,
# Nearest to existence: craftsmanship, backspin, territorial, man, postulates, kinetics, racked, argument,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0085 0.2159 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9911 0.2145 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9688 0.2172 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0084 0.2142 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0539 0.2147 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9634 0.2146 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9989 0.2145 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0001 0.2143 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0181 0.2170 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0145 0.2141 sec/batch
# Nearest to system: november, setting, timesharing, impairments, rewritten, distributed, designator, satellite,
# Nearest to be: condition, trivially, bards, modifications, pause, of, plaintext, hubris,
# Nearest to where: lucilla, clary, a, discriminate, parent, whores, relationship, bodmin,
# Nearest to only: sempron, have, narratives, sampling, idol, angering, grand, but,
# Nearest to most: known, piacenza, as, prejudiced, and, coelacanth, machpelah, had,
# Nearest to one: nine, five, six, zero, eight, two, seven, three,
# Nearest to three: six, two, one, five, zero, four, nine, seven,
# Nearest to can: subalgebra, useful, adm, choose, sip, be, encryption, foreman,
# Nearest to dr: winwood, richardson, gang, aunt, ormond, jeremy, technology, clauses,
# Nearest to freedom: enumeration, propagates, madhava, pertinent, mcdermott, technician, collectivism, hayek,
# Nearest to versions: flattening, tiber, encylopedia, compiler, windows, idiom, licklider, connes,
# Nearest to pressure: ale, eraser, lovable, mpa, pitted, regenerate, riots, steppe,
# Nearest to writers: bitnet, gardnerian, alumni, weinberg, ender, philosophers, novelists, fellows,
# Nearest to engine: engines, jumo, aircraft, kislev, reciprocating, turbofans, bathed, piston,
# Nearest to pope: longinus, gregory, disks, poverty, pisa, bestows, fabricius, eustace,
# Nearest to existence: craftsmanship, backspin, man, postulates, territorial, kinetics, argument, racked,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9939 0.2163 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9633 0.2148 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9583 0.2147 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9917 0.2151 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0142 0.2157 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0029 0.2147 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9791 0.2151 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9602 0.2149 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9553 0.2143 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0276 0.2163 sec/batch
# Nearest to system: november, impairments, timesharing, satellite, setting, exercise, rewritten, distributed,
# Nearest to be: condition, modifications, which, bards, plaintext, pause, can, trivially,
# Nearest to where: lucilla, clary, bodmin, spires, parent, a, whores, relationship,
# Nearest to only: sempron, have, sampling, narratives, type, least, numbers, angering,
# Nearest to most: known, as, tibeto, had, coelacanth, with, gnostic, resilient,
# Nearest to one: nine, zero, six, eight, five, two, seven, three,
# Nearest to three: two, six, one, five, zero, four, nine, seven,
# Nearest to can: subalgebra, adm, choose, useful, be, sip, borel, foreman,
# Nearest to dr: winwood, richardson, gang, arag, aunt, pital, ormond, technology,
# Nearest to freedom: enumeration, propagates, pertinent, madhava, mcdermott, technician, apologetics, hayek,
# Nearest to versions: compiler, tiber, encylopedia, connes, idiom, licklider, flattening, scandinavia,
# Nearest to pressure: ale, pitted, steppe, riots, lovable, regenerate, eraser, orioles,
# Nearest to writers: bitnet, alumni, novelists, philosophers, weinberg, gardnerian, satirists, fellows,
# Nearest to engine: engines, jumo, reciprocating, kislev, turbofans, aircraft, bathed, piston,
# Nearest to pope: longinus, disks, gregory, poverty, bestows, pisa, fabricius, eustace,
# Nearest to existence: man, craftsmanship, territorial, backspin, kinetics, postulates, argument, racked,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9854 0.2165 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0767 0.2151 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0380 0.2146 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0288 0.2145 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9400 0.2145 sec/batch
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8097 0.2152 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8792 0.2142 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9169 0.2147 sec/batch
# Nearest to system: setting, impairments, rewritten, exercise, branch, branko, station, amoeba,
# Nearest to be: that, which, of, it, can, the, as, before,
# Nearest to where: relationship, using, a, lucilla, useful, sometimes, the, then,
# Nearest to only: have, that, it, least, sempron, notice, number, but,
# Nearest to most: known, and, with, are, in, an, is, has,
# Nearest to one: nine, two, five, zero, six, eight, seven, three,
# Nearest to three: two, six, one, five, four, nine, zero, seven,
# Nearest to can: be, useful, subalgebra, or, are, damage, degrading, choose,
# Nearest to dr: winwood, technology, richardson, tupac, pital, altered, triggers, philistine,
# Nearest to freedom: propagates, human, liberty, fis, enumeration, moratorium, technician, smile,
# Nearest to versions: tiber, version, turboprop, ides, scandinavia, windows, idiom, had,
# Nearest to pressure: mpa, abreast, ale, heat, bardeen, aggravated, haemophiliac, pitted,
# Nearest to writers: novelists, satirists, winners, ender, fellows, alumni, science, autodidacts,
# Nearest to engine: engines, jumo, piston, turbofans, innsbruck, reciprocating, powered, combustion,
# Nearest to pope: gregory, papacy, eustace, poverty, fabricius, catholic, xiii, dominicans,
# Nearest to existence: craftsmanship, ucsd, noor, condoned, exist, mendeleev, kinetics, backspin,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8214 0.2161 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8602 0.2147 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8527 0.2151 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8643 0.2150 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8594 0.2143 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8783 0.2149 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8580 0.2149 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8564 0.2148 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8929 0.2159 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8733 0.2149 sec/batch
# Nearest to system: setting, impairments, station, osa, branch, exercise, for, brewed,
# Nearest to be: of, that, which, it, can, the, as, from,
# Nearest to where: relationship, lucilla, a, using, before, whores, useful, schoolmates,
# Nearest to only: have, least, that, notice, it, but, sempron, currently,
# Nearest to most: known, and, are, with, in, is, an, as,
# Nearest to one: nine, two, zero, eight, five, six, seven, three,
# Nearest to three: two, six, one, five, nine, four, zero, seven,
# Nearest to can: be, useful, or, subalgebra, are, parade, choose, boolean,
# Nearest to dr: winwood, technology, richardson, tupac, pital, altered, triggers, philistine,
# Nearest to freedom: human, propagates, liberty, moratorium, fis, technician, smile, legion,
# Nearest to versions: tiber, version, scandinavia, ides, encylopedia, windows, codex, idiom,
# Nearest to pressure: mpa, abreast, ale, aggravated, heat, haemophiliac, pitted, celsius,
# Nearest to writers: novelists, winners, satirists, fellows, science, ender, alumni, philosophers,
# Nearest to engine: engines, jumo, turbofans, piston, innsbruck, reciprocating, dickensian, combustion,
# Nearest to pope: papacy, gregory, xiii, fabricius, catholic, designating, eustace, poverty,
# Nearest to existence: craftsmanship, noor, exist, mendeleev, ucsd, kinetics, can, postulates,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8727 0.2161 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8210 0.2147 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8094 0.2150 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8383 0.2157 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9050 0.2159 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8298 0.2153 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9618 0.2150 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8926 0.2144 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8790 0.2148 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8119 0.2173 sec/batch
# Nearest to system: setting, impairments, exercise, locomotive, station, brewed, cellist, graphical,
# Nearest to be: of, that, which, it, can, deciding, as, does,
# Nearest to where: relationship, lucilla, using, before, schoolmates, spires, whores, iowa,
# Nearest to only: have, least, sempron, it, grants, since, provide, notice,
# Nearest to most: known, and, with, are, is, has, an, believe,
# Nearest to one: zero, nine, two, six, eight, five, seven, three,
# Nearest to three: two, six, one, five, four, nine, zero, seven,
# Nearest to can: be, or, subalgebra, useful, are, parade, adm, degrading,
# Nearest to dr: winwood, richardson, technology, triggers, altered, tupac, pital, slovakian,
# Nearest to freedom: liberty, propagates, human, moratorium, fis, smile, legion, enumeration,
# Nearest to versions: tiber, ides, scandinavia, encylopedia, codex, version, synergy, idiom,
# Nearest to pressure: mpa, ale, abreast, heat, aggravated, pitted, haemophiliac, bardeen,
# Nearest to writers: novelists, winners, fellows, satirists, science, ender, alumni, recipients,
# Nearest to engine: engines, jumo, turbofans, piston, reciprocating, innsbruck, combustion, exhaust,
# Nearest to pope: papacy, gregory, fabricius, xiii, eustace, designating, catholic, poverty,
# Nearest to existence: craftsmanship, noor, exist, ucsd, cumbria, mendeleev, kinetics, continua,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8243 0.2151 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8816 0.2147 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7833 0.2147 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8644 0.2148 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8427 0.2164 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8550 0.2145 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8845 0.1419 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8554 0.2151 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8171 0.2148 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8692 0.2151 sec/batch
# Nearest to system: setting, graphical, impairments, exercise, branch, locomotive, osa, upgrading,
# Nearest to be: of, that, which, it, can, as, before, the,
# Nearest to where: relationship, lucilla, before, whores, useful, schoolmates, using, judaeo,
# Nearest to only: have, it, least, notice, sempron, excluding, provide, currently,
# Nearest to most: known, and, are, with, is, in, such, an,
# Nearest to one: nine, two, five, eight, seven, six, zero, three,
# Nearest to three: two, one, six, five, nine, four, seven, zero,
# Nearest to can: useful, be, or, subalgebra, degrading, damage, are, parade,
# Nearest to dr: winwood, richardson, technology, triggers, altered, pital, tupac, slovakian,
# Nearest to freedom: propagates, liberty, human, fis, moratorium, smile, legion, enumeration,
# Nearest to versions: tiber, ides, scandinavia, version, codex, irwin, encylopedia, windows,
# Nearest to pressure: mpa, abreast, haemophiliac, heat, ale, pressures, aggravated, bardeen,
# Nearest to writers: novelists, winners, satirists, fellows, ender, alumni, science, recipients,
# Nearest to engine: engines, jumo, turbofans, piston, innsbruck, reciprocating, combustion, exhaust,
# Nearest to pope: papacy, gregory, fabricius, poverty, innocent, xiii, eustace, benedict,
# Nearest to existence: exist, craftsmanship, noor, ucsd, can, continua, gibbons, man,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8142 0.2173 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8440 0.2147 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8034 0.2149 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8368 0.2146 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8541 0.2145 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8382 0.2147 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8704 0.2161 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7339 0.2146 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8310 0.2148 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7740 0.2143 sec/batch
# Nearest to system: setting, for, impairments, branch, exercise, graphical, locomotive, branko,
# Nearest to be: that, of, which, it, can, the, there, before,
# Nearest to where: relationship, before, using, a, lucilla, useful, sometimes, in,
# Nearest to only: have, it, least, but, notice, that, sempron, number,
# Nearest to most: known, and, are, is, with, in, an, as,
# Nearest to one: two, five, zero, six, eight, seven, nine, three,
# Nearest to three: two, six, one, five, four, nine, zero, seven,
# Nearest to can: or, be, useful, are, subalgebra, there, example, is,
# Nearest to dr: winwood, technology, altered, richardson, triggers, pital, tupac, liebert,
# Nearest to freedom: propagates, liberty, moratorium, human, fis, legion, smile, technician,
# Nearest to versions: tiber, scandinavia, ides, version, irwin, turboprop, synergy, windows,
# Nearest to pressure: mpa, heat, abreast, pitted, bardeen, ale, haemophiliac, aggravated,
# Nearest to writers: novelists, winners, satirists, ender, fellows, science, alumni, autodidacts,
# Nearest to engine: engines, jumo, turbofans, piston, innsbruck, reciprocating, servicemen, dickensian,
# Nearest to pope: papacy, gregory, fabricius, poverty, innocent, xiii, eustace, benedict,
# Nearest to existence: exist, craftsmanship, noor, ucsd, gibbons, man, cumbria, continua,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7520 0.2156 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8117 0.2155 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8651 0.2147 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8336 0.2146 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8204 0.2145 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8905 0.2148 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8074 0.2150 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8252 0.2162 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8159 0.2145 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8366 0.2152 sec/batch
# Nearest to system: setting, branch, for, the, nebulae, impairments, branko, locomotive,
# Nearest to be: of, that, which, the, it, can, as, before,
# Nearest to where: relationship, using, before, a, sometimes, lucilla, judaeo, useful,
# Nearest to only: have, it, sempron, least, notice, that, but, grants,
# Nearest to most: known, and, are, with, has, in, is, as,
# Nearest to one: two, nine, six, five, zero, eight, seven, three,
# Nearest to three: two, six, one, five, nine, four, zero, seven,
# Nearest to can: or, be, useful, are, subalgebra, degrading, example, there,
# Nearest to dr: winwood, technology, altered, tupac, triggers, richardson, liebert, plain,
# Nearest to freedom: liberty, human, moratorium, propagates, fis, freedoms, enumeration, sustainability,
# Nearest to versions: tiber, ides, irwin, version, encylopedia, anymore, codex, synergy,
# Nearest to pressure: mpa, heat, bardeen, ale, abreast, pressures, haemophiliac, pitted,
# Nearest to writers: novelists, winners, satirists, fellows, ender, alumni, sexton, natives,
# Nearest to engine: engines, jumo, turbofans, innsbruck, piston, reciprocating, dickensian, combustion,
# Nearest to pope: papacy, gregory, innocent, poverty, fabricius, dominicans, eustace, designating,
# Nearest to existence: exist, craftsmanship, noor, ucsd, cumbria, mendeleev, gibbons, man,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8515 0.2156 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8506 0.2148 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8193 0.2155 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8232 0.2147 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8666 0.2146 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8399 0.2152 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8349 0.2147 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8559 0.2148 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8049 0.2156 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8143 0.2142 sec/batch
# Nearest to system: setting, for, the, a, nebulae, impairments, locomotive, station,
# Nearest to be: of, that, which, the, it, as, can, is,
# Nearest to where: using, relationship, a, before, lucilla, sometimes, given, the,
# Nearest to only: have, it, least, notice, number, sempron, but, a,
# Nearest to most: known, and, are, with, in, has, as, these,
# Nearest to one: two, eight, six, zero, nine, seven, five, three,
# Nearest to three: two, one, six, five, four, zero, nine, seven,
# Nearest to can: be, or, are, useful, degrading, without, there, enables,
# Nearest to dr: winwood, technology, triggers, tupac, altered, pital, liebert, philistine,
# Nearest to freedom: liberty, human, moratorium, propagates, fis, freedoms, smile, free,
# Nearest to versions: tiber, ides, irwin, version, scandinavia, synergy, codex, licencing,
# Nearest to pressure: mpa, heat, pressures, ale, pitted, bardeen, haemophiliac, abreast,
# Nearest to writers: novelists, winners, fellows, satirists, ender, alumni, science, sexton,
# Nearest to engine: engines, jumo, turbofans, innsbruck, piston, dickensian, reciprocating, combustion,
# Nearest to pope: papacy, gregory, innocent, poverty, fabricius, dominicans, xiii, designating,
# Nearest to existence: exist, noor, craftsmanship, cumbria, ucsd, mendeleev, gibbons, continua,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8492 0.2161 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8251 0.2156 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9418 0.2151 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8938 0.2159 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9105 0.2146 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8063 0.2149 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7809 0.2139 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8315 0.2143 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7915 0.2150 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8521 0.2155 sec/batch
# Nearest to system: setting, the, nebulae, station, locomotive, for, branch, osa,
# Nearest to be: that, of, which, can, the, as, it, is,
# Nearest to where: using, before, relationship, a, sometimes, lucilla, include, micheal,
# Nearest to only: have, it, least, notice, provide, that, but, grants,
# Nearest to most: known, and, are, has, with, as, many, such,
# Nearest to one: nine, eight, two, seven, five, six, zero, three,
# Nearest to three: two, one, six, five, nine, four, zero, seven,
# Nearest to can: be, or, useful, are, subalgebra, example, degrading, without,
# Nearest to dr: winwood, technology, triggers, tupac, altered, pital, liebert, gang,
# Nearest to freedom: liberty, human, propagates, moratorium, recipients, freedoms, fis, legion,
# Nearest to versions: tiber, ides, version, irwin, windows, encylopedia, codex, licencing,
# Nearest to pressure: mpa, ale, pitted, heat, katherine, abreast, pressures, bardeen,
# Nearest to writers: winners, novelists, fellows, satirists, science, ender, alumni, recipients,
# Nearest to engine: engines, jumo, turbofans, innsbruck, piston, dickensian, slopes, combustion,
# Nearest to pope: papacy, gregory, fabricius, innocent, poverty, dominicans, eustace, epirus,
# Nearest to existence: craftsmanship, exist, noor, ucsd, cumbria, gibbons, mendeleev, continua,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8624 0.2164 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8238 0.2145 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
